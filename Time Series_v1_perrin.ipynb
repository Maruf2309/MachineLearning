# %% [markdown]
# # TimeSeries - ARIMA & Seasonal ARIMA

# %% [markdown]
# ### Autoregressive integrated moving Averages (ARIMA)

# %% [markdown]
# 1. The General Process for ARIMA models is following:
#     - Visualize the time series data
#     - Make the time series data stationary
#     - Plot the correlation & AutoCorrelation Charts
#     - Construct the ARIMA Model or Seasonal ARIMA based on the data
#     - Use the model to prediction

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings as wr
wr.filterwarnings('ignore')
# %matplotlib inline

# %%
df = pd.read_csv("E:\M60\ml_dataset\perrin-freres-monthly-champagne.csv")
df.head()
# Out:
#      Month  Perrin Freres monthly champagne sales millions ?64-?72
# 0  1964-01                                             2815.0
# 1  1964-02                                             2672.0
# 2  1964-03                                             2755.0
# 3  1964-04                                             2721.0
# 4  1964-05                                             2946.0

# %%
df.tail()
# Out:
#                                                  Month  \
# 102                                            1972-07
# 103                                            1972-08
# 104                                            1972-09
# 105                                                NaN
# 106  Perrin Freres monthly champagne sales millions...
#
#      Perrin Freres monthly champagne sales millions ?64-?72
# 102                                             4298.0
# 103                                             1413.0
# 104                                             5877.0
# 105                                                NaN
# 106                                                NaN

# %% [markdown]
# #### Change the column name

# %%
## Clean up data
df.columns=['Month','sales']
df.head()
# Out:
#      Month   sales
# 0  1964-01  2815.0
# 1  1964-02  2672.0
# 2  1964-03  2755.0
# 3  1964-04  2721.0
# 4  1964-05  2946.0

# %% [markdown]
# #### Drop unnecessay columns

# %%
# drop last 2 rows
df.drop(106, axis=0, inplace=True)

# %%
df.tail()
# Out:
#        Month   sales
# 101  1972-06  5312.0
# 102  1972-07  4298.0
# 103  1972-08  1413.0
# 104  1972-09  5877.0
# 105      NaN     NaN

# %%
# drop las 2 rows
df.drop(105, axis=0, inplace=True)

# %%
df.tail()
# Out:
#        Month   sales
# 100  1972-05  4618.0
# 101  1972-06  5312.0
# 102  1972-07  4298.0
# 103  1972-08  1413.0
# 104  1972-09  5877.0

# %% [markdown]
# #### Convert Month into Datetime - Timeseries

# %%
df['Month'] = pd.to_datetime(df['Month'])
df.head()
# Out:
#        Month   sales
# 0 1964-01-01  2815.0
# 1 1964-02-01  2672.0
# 2 1964-03-01  2755.0
# 3 1964-04-01  2721.0
# 4 1964-05-01  2946.0

# %%
# Set index - due to timeindex
df.set_index('Month', inplace=True)

# %%
df.head()
# Out:
#              sales
# Month
# 1964-01-01  2815.0
# 1964-02-01  2672.0
# 1964-03-01  2755.0
# 1964-04-01  2721.0
# 1964-05-01  2946.0

# %%
df.describe().T
# Out:
#        count         mean          std     min     25%     50%     75%  \
# sales  105.0  4761.152381  2553.502601  1413.0  3113.0  4217.0  5221.0
#
#            max
# sales  13916.0

# %% [markdown]
# ## Step 2: Visualize the Data

# %%
df.plot()
plt.show()

# %%
## Testing for stationary
from statsmodels.tsa.stattools import adfuller

# %%
# HO: It is non stationary  (Null hypothesis will be rejected if p value <=0.5)
# H1: It is stationary

def adfuller_test(sales):
    result = adfuller(sales)
    labels = ['ADF Test Statistics','p-value','#lags Used','#Observations Used']
    for value, label in zip(result, labels):
        print(label+' : '+str(value))
        if result[1] <= 0.05:       # result[1] indicating accessing p value
            print("Strong Evidence Against the Null Hypothesis (Ho), reject the alternat hypothesis")
        else:
            print("Week evidence against the Null Hypothesis, accept H0, the data is non-stationary")

# %%
adfuller_test(df['sales'])
# Out:
# ADF Test Statistics : -1.8335930563276246
# Week evidence against the Null Hypothesis, accept H0, the data is non-stationary
# p-value : 0.3639157716602442
# Week evidence against the Null Hypothesis, accept H0, the data is non-stationary
# #lags Used : 11
# Week evidence against the Null Hypothesis, accept H0, the data is non-stationary
# #Observations Used : 93
# Week evidence against the Null Hypothesis, accept H0, the data is non-stationary

# %%
.36 > 0.05 # Since the p value is greater than significance value (0.05) so, accept null hypothesis, the data is non-stationary
# Out:
# True

# %%
def adfuller_test(sales):
    result = adfuller(sales)
    labels = ['ADF Test Statistics','p-value','#lags Used','#Observations Used']
    for value,label in zip(result,labels):
        print(label+' : '+str(value))
    # Use a variable to store the result of the p-value comparison
    reject_null = result[1] <= 0.05
    # Print the message outside of the for loop based on the variable
    if reject_null:
        print("Strong Evidence Against The Null Hypothesis (H0), reject the null hypothesis")
    else:
        print("Weak Evidence Against The Null Hypothesis, accept H0, time series has a unit root,indicating is a non-stationary,  ")

adfuller_test(df['sales'])
# Out:
# ADF Test Statistics : -1.8335930563276246
# p-value : 0.3639157716602442
# #lags Used : 11
# #Observations Used : 93
# Weak Evidence Against The Null Hypothesis, accept H0, time series has a unit root,indicating is a non-stationary,

# %% [markdown]
# 1. Since the data proved or found as non-stationary, so need to make it stationary
# 2. Calcuting difference may be effective to make it stationary

# %% [markdown]
# ### Differencing

# %%
df['seasonal first difference'] = df['sales'] - df['sales'].shift(1)
df['seasonal difference'] = df['sales'] - df['sales'].shift(12)
df.head(14)
# Out:
#              sales  seasonal first difference  seasonal difference
# Month
# 1964-01-01  2815.0                        NaN                  NaN
# 1964-02-01  2672.0                     -143.0                  NaN
# 1964-03-01  2755.0                       83.0                  NaN
# 1964-04-01  2721.0                      -34.0                  NaN
# 1964-05-01  2946.0                      225.0                  NaN
# 1964-06-01  3036.0                       90.0                  NaN
# 1964-07-01  2282.0                     -754.0                  NaN
# 1964-08-01  2212.0                      -70.0                  NaN
# 1964-09-01  2922.0                      710.0                  NaN
# 1964-10-01  4301.0                     1379.0                  NaN
# 1964-11-01  5764.0                     1463.0                  NaN
# 1964-12-01  7312.0                     1548.0                  NaN
# 1965-01-01  2541.0                    -4771.0               -274.0
# 1965-02-01  2475.0                      -66.0               -197.0

# %% [markdown]
# 1. Shift(1), its checking data by 1 day shifting / see the data change over each day ( or particular time period)
# 2. Some time we need to check a specific periodical diffence with the data

# %% [markdown]
# #### Important Notes:

# %% [markdown]
# 1. Since the data in not stationary, it is seasonal over 12 month data, so shifting 1 will be good choice, we must do it as seasonal (12 Months) difference
# 2. See the plot data is seasonal over 12 month seasonal, we seasonal difference need to check

# %%
### Again test dickey fuller test
adfuller_test(df['seasonal difference'].dropna())  # dropna is mandatory, if lags # 0 --> it perfect stationary
# Out:
# ADF Test Statistics : -7.626619157213164
# p-value : 2.060579696813685e-11
# #lags Used : 0
# #Observations Used : 92
# Strong Evidence Against The Null Hypothesis (H0), reject the null hypothesis

# %%
2.060579696813685e-11 < 0.05  # Now p value is less then p significance value i.e 0.05, so now reject null hypothesis
# Out:
# True

# %%
df['seasonal difference'].plot() # now data looks almost stationary, here is some constant mean/ median over the time
plt.show()

# %% [markdown]
# 1. Once the data becomes stationary, we need to stop over there
# 2. if there are small variance, that mean we are taking the p value as .05, if p value exactly 0 or ZERO that wil be wonderful stationary graph

# %% [markdown]
# ## Auto Regressive Model

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# from pandas.tools.plotting import autocorrelation_plot  # This removed from pandas
from pandas.plotting import autocorrelation_plot
autocorrelation_plot(df['sales'])
plt.show()

# %% [markdown]
# * <b> Autocorrelation Plot:</b>
# The autocorrelation_plot function calculates and visualizes the autocorrelation of a time series data.
# Autocorrelation measures how a variable correlates with itself at different time lags (shifts).
# It’s commonly used for time series analysis to identify patterns related to seasonality or cyclic behavior.
#
# * <b>Interpreting the Graph:</b>
# - The resulting graph shows the autocorrelation values for different lags <b>(time shifts)</b>.
# - The x-axis represents the <b>lag</b>, which indicates how many time steps back we’re comparing the data.
# - The y-axis represents the <b>autocorrelation</b> value, ranging from -1 to 1.
# * Key points:
#
# - Peaks or spikes above the dashed horizontal lines indicate significant <b>positive autocorrelation.</b>
# - Troughs below the lines indicate significant <b>negative autocorrelation</b>
# - The blue line represents the autocorrelation at various lag times.
# - The confidence intervals (dashed lines) help identify statistically significant correlations.
#
# ** Remember that this plot helps us understand how the ‘sales’ data is correlated with its past values at different time lags. Peaks in the plot can indicate potential seasonality or repeating patterns in the sales data. If you have specific data, you can apply this technique to explore its autocorrelation behavior

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# #### Q1. define positive autocorrelation & negative autocorrelation, which one is good?

# %% [markdown]
# Let’s delve into the definitions of positive autocorrelation and negative autocorrelation:
#
# * <b>Positive Autocorrelation:</b>
#
# - Positive autocorrelation occurs when a time series variable is positively correlated with its own past values (lags).
# - In other words, when the current value of a variable tends to be higher when its past values were also higher, we observe positive autocorrelation.
# - Example: If yesterday’s stock price was high, and today’s stock price is also high, there is positive autocorrelation.
# - Good or Bad?: Positive autocorrelation can be both good and bad, depending on the context. It’s good when it indicates a predictable pattern (e.g., seasonality) that can be leveraged for forecasting. However, in some cases (like financial markets), extreme positive autocorrelation might lead to bubbles or crashes.
# * <b>Negative Autocorrelation:</b>
# - Negative autocorrelation occurs when a time series variable is negatively correlated with its own past values (lags).
# - When the current value of a variable tends to be lower when its past values were higher, we observe negative autocorrelation.
# - Example: If yesterday’s temperature was high, and today’s temperature is lower, there is negative autocorrelation.
# - Good or Bad?: Negative autocorrelation can also be both good and bad. It’s good when it indicates a balancing effect (e.g., temperature regulation). However, extreme negative autocorrelation might disrupt stability (e.g., erratic stock prices).
#
# ** In summary, both positive and negative autocorrelation have their significance, and their interpretation depends on the specific domain and context of the data being analyzed. Neither is inherently “good” or “bad”; it’s about understanding the underlying patterns and adjusting our strategies accordingly.

# %% [markdown]
# ## Final Throughts on Autocorrelation and  Partial Autocorrelation

# %% [markdown]
# * Identification of an <b>AR Model</b> is often is the best done with the PACF (do it first)
#   * For an AR Model, the theoritical PACF "Shuts off" past the order of the model. The phrase "shuts off" means that in the theory the partial autocorrelation are equal to 0 beyond the point. Put anohter way, the number of non-zero partial autocorrelations gives the order of the AR model. By the "order of the model" we mean the most extreme lag of x that is used as a predictor
# * Identification of an MA (Moving Average) Model is often is the best done with the ACF rather than the PACF
#  * For an AR Model, the theoritical PACF does not Shuts off but instead tapers toward 0 in some manner. A clearer pattern for an MA model is the ACF. The ACF will have non-zero autocorrelations only at lags involved in the model.
#
# * Remember AR includes three values:
#     * p, d, q AR Models lags d differencing q MA lags
# - p: AR Model lags
# - q: MA Model lags
# - d: differencing

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# %%
import statsmodels as sm 
import statsmodels.api as sm # for graphics.tsa

# %%
fig = plt.figure(figsize=(12, 8))
ax1 = fig.add_subplot(211)
fig = sm.graphics.tsa.plot_acf(df['seasonal first difference'].iloc[13:], lags=40, ax=ax1)
ax2 = fig.add_subplot(212)
fig = sm.graphics.tsa.plot_pacf(df['seasonal first difference'].iloc[13:], lags=40, ax=ax2) # Partial

# %% [markdown]
# The first digit (2) represents the number of rows in the subplot grid.
# The second digit (2) represents the number of columns in the subplot grid.
# The third digit (1) specifies the position of the subplot within the grid.
#
# We have a 2x2 grid (2 rows and 2 columns).
# The subplot we’re adding is positioned at the first slot (top left corner) of the grid.
# This means that ax1 corresponds to the top left subplot in the figure. Similarly, you can create other subplots using similar notation, adjusting the third digit to position them within the grid. For example:
#
# ax2 = fig.add_subplot(222) would be the top right subplot.
# ax3 = fig.add_subplot(223) would be the bottom left subplot.
# ax4 = fig.add_subplot(224) would be the bottom right subplot.

# %%
# For non seasonal data
# p:1, d=1, q=1
from statsmodels.tsa.arima_model import ARIMA

# %%
from statsmodels.tsa.arima.model import ARIMA
model = ARIMA(df['sales'], order=(1, 1, 1))
model_fit = model.fit()

# %%
# Model Summary
model_fit.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                  sales   No. Observations:                  105
# Model:                 ARIMA(1, 1, 1)   Log Likelihood                -952.814
# Date:                Fri, 31 May 2024   AIC                           1911.627
# Time:                        22:02:16   BIC                           1919.560
# Sample:                    01-01-1964   HQIC                          1914.841
#                          - 09-01-1972
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.4545      0.114      3.999      0.000       0.232       0.677
# ma.L1         -0.9666      0.056    -17.316      0.000      -1.076      -0.857
# sigma2      5.226e+06   6.17e+05      8.473      0.000    4.02e+06    6.43e+06
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.91   Jarque-Bera (JB):                 2.59
# Prob(Q):                              0.34   Prob(JB):                         0.27
# Heteroskedasticity (H):               3.40   Skew:                             0.05
# Prob(H) (two-sided):                  0.00   Kurtosis:                         3.77
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %% [markdown]
# ### Result Interpretation

# %% [markdown]
# <b> Dependent Variable: </b>
# The dependent variable in your model is labeled as ‘sales’. This means that the model aims to predict or explain variations in sales data.
#
# <b> Model Information:</b>
# The model you’ve used is an ARIMA(1, 1, 1) model.
# ARIMA: Stands for AutoRegressive Integrated Moving Average.
# (1, 1, 1): Represents the order of the ARIMA model.
# p (autoregressive order): 1 (one lag term)
# d (differencing order): 1 (first difference)
# q (moving average order): 1 (one moving average term)
#
#
# Method and Estimation:
# The method used for estimation is ‘css-mle’, which stands for Conditional Sum of Squares with Maximum Likelihood Estimation.
# The log likelihood value is -952.814, and the AIC (Akaike Information Criterion) is 1911.627. Lower AIC values indicate better model fit.
# Sample Range:
# The model was estimated using data from “01-01-1964” to “09-01-1972”.
# Coefficient Section:
# ar.L1 (Autoregressive Coefficient):
# Coefficient: -0.9545
# Standard Error: 0.116
# z-value: -8.199
# p-value: 0.000 (highly significant)
# Confidence Interval (95%): [-1.182, -0.727]
#
# ma.L1 (Moving Average Coefficient):
# Coefficient: 0.4545
# Standard Error: 0.114
# z-value: 3.999
# p-value: 0.000 (highly significant)
# Confidence Interval (95%): [0.025, 0.975]
# Variance Estimate:
# The estimated variance of residuals (sigma^2) is 5.226e+06 (approximately 5.2 million).
# Model Fit Tests:
# Ljung-Box (Q) test: The p-value is 0.34, suggesting no significant autocorrelation in the residuals.
# Jarque-Bera (JB) test: The p-value is 0.27, indicating that the residuals are approximately normally distributed.
# Heteroskedasticity (H) test: The p-value is 0.00, suggesting heteroskedasticity (non-constant variance) in the residuals.
#
# In summary, this ARIMA model captures the temporal dependencies in the sales data, considering both autoregressive and moving average components. The low AIC value indicates a good fit, but further diagnostics (such as residual plots) are recommended to validate the model.

# %% [markdown]
# * This model not works well

# %%
df['forecast'] = model_fit.predict(start=90, end=103, dynamic=True)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 9))
plt.plot(df.index, df['sales'], label='Actual Sales')
plt.plot(df.index, df['forecast'], label='Forecast', linestyle='--', color='orange')
plt.xlabel('Date')
plt.ylabel('Sales')
plt.title('Actual Sales vs. Forecast')
plt.legend()
plt.show()

# %%
df
# Out:
#              sales  seasonal first difference  seasonal difference  \
# Month
# 1964-01-01  2815.0                        NaN                  NaN
# 1964-02-01  2672.0                     -143.0                  NaN
# 1964-03-01  2755.0                       83.0                  NaN
# 1964-04-01  2721.0                      -34.0                  NaN
# 1964-05-01  2946.0                      225.0                  NaN
# ...            ...                        ...                  ...
# 1972-05-01  4618.0                     -170.0               -392.0
# 1972-06-01  5312.0                      694.0                438.0
# 1972-07-01  4298.0                    -1014.0               -335.0
# 1972-08-01  1413.0                    -2885.0               -246.0
# 1972-09-01  5877.0                     4464.0                -74.0
#
#                forecast
# Month
# 1964-01-01          NaN
# 1964-02-01          NaN
# 1964-03-01          NaN
# 1964-04-01          NaN
# 1964-05-01          NaN
# ...                 ...
# 1972-05-01  5062.884293
# 1972-06-01  5062.901909
# 1972-07-01  5062.909915
# 1972-08-01  5062.913553
# 1972-09-01          NaN
#
# [105 rows x 4 columns]

# %% [markdown]
# ## Model : SARIMA

# %%
import statsmodels.api as sm

# %%
model = sm.tsa.statespace.SARIMAX(df['sales'], order=(1,1,1), seasonal_order=(1,1,1,12))
results = model.fit()

df['forecast'] = results.predict(start=90, end=103, dynamic=True)
df[['sales', 'forecast']].plot(figsize=(12,8))
plt.show()

# %% [markdown]
# * Now its look pretty good, but need to see my future prediction
# * its looks better than ARIMA Model

# %%
# See Future Prediction
from pandas.tseries.offsets import DateOffset
future_dates = [df.index[-1] + DateOffset(months=x) for x in range(0,24)]

future_datest_df = pd.DataFrame(index=future_dates[1:], columns=df.columns)
future_datest_df.tail()
# Out:
#            sales seasonal first difference seasonal difference forecast
# 1974-04-01   NaN                       NaN                 NaN      NaN
# 1974-05-01   NaN                       NaN                 NaN      NaN
# 1974-06-01   NaN                       NaN                 NaN      NaN
# 1974-07-01   NaN                       NaN                 NaN      NaN
# 1974-08-01   NaN                       NaN                 NaN      NaN

# %%
future_df = pd.concat([df, future_datest_df])

# %%
future_df['forecast']= results.predict(start=104, end=120, dynamic=True)
future_df[['sales','forecast']].plot(figsize=(12,8))
plt.show()

# %% [markdown]
# ### Note-Take away

# %% [markdown]
# 1. Visualize- plot: there is seasonality in dataset
# 2. Stationary : not moving or not intended to be moved- lots of ups & down/ not fixed label of patter (mean/ median/mode) its fluctuating over the time, so it not stationary data, we need to make it stationary for better prediction
# 3. So the data is not stationary (constact) this s a Null Hypothesis in general visualization

# %% [markdown]
# #### Differencing

# %%
df['sales'][:5] # Initial data
# Out:
# Month
# 1964-01-01    2815.0
# 1964-02-01    2672.0
# 1964-03-01    2755.0
# 1964-04-01    2721.0
# 1964-05-01    2946.0
# Name: sales, dtype: float64

# %%
df['sales'].shift(1)[:5]  # shifting 1 position
# Out:
# Month
# 1964-01-01       NaN
# 1964-02-01    2815.0
# 1964-03-01    2672.0
# 1964-04-01    2755.0
# 1964-05-01    2721.0
# Name: sales, dtype: float64

# %%
df['sales'].shift(5)
# Out:
# Month
# 1964-01-01        NaN
# 1964-02-01        NaN
# 1964-03-01        NaN
# 1964-04-01        NaN
# 1964-05-01        NaN
#                ...
# 1972-05-01    12670.0
# 1972-06-01     4348.0
# 1972-07-01     3564.0
# 1972-08-01     4577.0
# 1972-09-01     4788.0
# Name: sales, Length: 105, dtype: float64

# %% [markdown]
# ## Offset- Test

# %%
import pandas as pd

# Create a timestamp for the current date and time
now = pd.Timestamp.now()

# Add a day
print("Add a day:", now + pd.offsets.DateOffset(days=1))

# Add a week
print("Add a week:", now + pd.offsets.DateOffset(weeks=1))

# Add a month
print("Add a month:", now + pd.offsets.DateOffset(months=1))

# Add an hour
print("Add an hour:", now + pd.offsets.DateOffset(hours=1))

# Add a day and replace the hour
print("Add a day, replace the hour:", now + pd.offsets.DateOffset(days=1, hour=13))

# Add a month and normalize (set time to midnight)
print("Add a month, normalize:", now + pd.offsets.DateOffset(month=1, normalize=True))

# Add 2 days across DST change (considering time zones)
print("Add 2 days across DST change:", pd.Timestamp("2022-11-05 00:00:00", tz="America/Chicago") + pd.offsets.DateOffset(days=2))

# Add 2 days across DST change (with Timedelta, no adjustment)
print("Add 2 days across DST change (with Timedelta, no adjustment):", pd.Timestamp("2022-11-05 00:00:00", tz="America/Chicago") + pd.Timedelta(days=2))
# Out:
# Add a day: 2024-06-01 22:50:29.392987
# Add a week: 2024-06-07 22:50:29.392987
# Add a month: 2024-06-30 22:50:29.392987
# Add an hour: 2024-05-31 23:50:29.392987
# Add a day, replace the hour: 2024-06-01 13:50:29.392987
# Add a month, normalize: 2024-01-31 00:00:00
# Add 2 days across DST change: 2022-11-07 00:00:00-06:00
# Add 2 days across DST change (with Timedelta, no adjustment): 2022-11-06 23:00:00-06:00

# %%
# Beginning of the quarter
print("Beginning of the quarter:", pd.date_range(start="2022-01-01", freq="QS", periods=4))

# Beginning of the month
print("Beginning of the month:", pd.date_range(start="2022-01-01", freq="MS", periods=4))

# Beginning of every 3rd month
print("Beginning of every 3rd month:", pd.date_range(start="2022-01-01", freq="3MS", periods=4))
# Out:
# Beginning of the quarter: DatetimeIndex(['2022-01-01', '2022-04-01', '2022-07-01', '2022-10-01'], dtype='datetime64[ns]', freq='QS-JAN')
# Beginning of the month: DatetimeIndex(['2022-01-01', '2022-02-01', '2022-03-01', '2022-04-01'], dtype='datetime64[ns]', freq='MS')
# Beginning of every 3rd month: DatetimeIndex(['2022-01-01', '2022-04-01', '2022-07-01', '2022-10-01'], dtype='datetime64[ns]', freq='3MS')

# %% [markdown]
# The freq parameter specifies the frequency (offset alias) for generating date ranges. In the examples above:
# - "QS": Quarterly start frequency
# - "MS": Monthly start frequency
# - "3MS": Every 3rd month start frequency
#
# - These examples demonstrate how you can manipulate dates using both direct DateOffset usage and convenient offset aliases. Feel free to adapt them to your specific use case!

# %%
import pandas as pd
import numpy as np

# Create a sample time series DataFrame
dates = pd.date_range(start='2024-01-01', periods=10, freq='M')
sales_data = np.random.randint(low=50, high=100, size=10)
df = pd.DataFrame({'Date': dates, 'Sales': sales_data})

# Calculate a 3-month moving average
df['Moving_Avg'] = df['Sales'].rolling(window=3).mean()

print(df)
# Out:
#         Date  Sales  Moving_Avg
# 0 2024-01-31     56         NaN
# 1 2024-02-29     94         NaN
# 2 2024-03-31     97   82.333333
# 3 2024-04-30     58   83.000000
# 4 2024-05-31     77   77.333333
# 5 2024-06-30     69   68.000000
# 6 2024-07-31     95   80.333333
# 7 2024-08-31     54   72.666667
# 8 2024-09-30     98   82.333333
# 9 2024-10-31     99   83.666667

# %%
from statsmodels.tsa.holtwinters import ExponentialSmoothing

# Fit an exponential smoothing model
model = ExponentialSmoothing(df['Sales'], trend='add', seasonal='add', seasonal_periods=3)
fitted_model = model.fit()

# Forecast future values
forecast = fitted_model.forecast(steps=3)

print(forecast)
# Out:
# 10    84.779405
# 11    97.773208
# 12    89.221896
# dtype: float64

# %%
from sklearn.linear_model import LinearRegression

# Create a simple linear regression model
X = df.index.values.reshape(-1, 1)
y = df['Sales']
model = LinearRegression()
model.fit(X, y)

# Predict future values
future_X = np.array([[10], [11], [12]])  # Assuming future indices
forecast_linear = model.predict(future_X)

print(forecast_linear)
# Out:
# [89.8        91.63636364 93.47272727]
